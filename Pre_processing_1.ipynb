# %% [markdown]
# # Pre-processing

# %% [markdown]
# # 1.Modality

# %% [markdown]
# *   Image reconstruction algorithms
# *   Denoising
# * Artefact correction
# * Standard Units

# %% [markdown]
# #2.Orientation

# %% [markdown]
# *   Same physical dimension

# %% [markdown]
# #3.Resampling

# %% [markdown]
# * Physical resolution
# * Physical size
#
#   * Padding
#   * Cropping
#
# Final size = 128x128x128

# %% [markdown]
# # 4.Normalization and Standardization

# %% [markdown]
# * intensity standardization
# * [-1,1]
#
#
# ---
#
#
# * Normalization
#   * X-Ray
#     * Z-Normalization
#   * CT
#   * MRI
#     * Z-Normalization
#   * PET
#   * US
#     * Z-Normalization
#
#
#
# ---
#
#
# * Standardization
#   * X-Ray
#     * 1:255
#   * CT
#     * 1:3071
#   * MRI
#     * Min-Max
#   * PET
#     * Clip 20-40
#   * US
#     * 1:255
# ---
#
# * Windowing
# * Cropping
# * Log
# ---
#
# * [ لینک مقاله اول](https://ieeexplore.ieee.org/document/8625388)
# * [لینک مقاله دوم](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8607477/)

# %% [markdown]
# #Voxel

# %% [markdown]
# A voxel is a unit of graphic information that defines a point in three-dimensional space

# %% [markdown]
# # Coordinate

# %% [markdown]
# A coordinate system is a method for identifying the location of a point
#
#
# [لینک ](https://theaisummer.com/medical-image-coordinates/)

# %% [markdown]
# # Physical and Voxel coordinates

# %% [markdown]
# * world
#   * Every medical modality has its own coordinate system , but there is only one world coordinate system to define the position and orientation of each modality.
# * anatomical
#   * axial plane
#
#   * sagittal plane
#
#   * coronal plane
# * medical image coordinate system(Voxel space)
#   * i
#   * j
#   * k

# %% [markdown]
# ![Medical-image-coordinate-systems.png](data:image/png;base64,...)

# %% [markdown]
#  * R =   from left towards right
#  * L =   from right towards left
#
#
#
#  * P =   from anterior towards posterior
#  * A =   from posterior towards anterior
#
#
#  * S =   from inferior towards superior
#  * I =   from superior towards inferior
#
# ​
# LPS - RAS
# ​

# %% [markdown]
# # Affine transformation

# %% [markdown]
#  elements indexed by A represent translation and t-indexed elements represent rotation

# %% [markdown]
# * the inverse of the affine gives the mapping from world to voxel.
# * As a consequence, we can go from voxel space described by A of one medical image to another voxel space of another modality B.
# * In this way, both medical images “live” in the same voxel space.

# %% [markdown]
# ![ijk.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# [مقالات بیشتر](https://www.slicer.org/wiki/Coordinate_systems)
